# %%
import bs4, os
from pymorphy2 import tokenizers
import pymorphy2 as pm
import pandas as pd

import sklearn
from sklearn.model_selection import KFold

import numpy as np
import sklearn_crfsuite
from sklearn_crfsuite import metrics

# %% [markdown]
# Parsing annotation info from xml files
#
# *Парсим информацию о разметке из xml-файлов*

# %%
def parsefile(fn):
    f = open(fn, encoding = 'utf-8')
    s = f.read()
    f.close()
    soup =bs4.BeautifulSoup(s, "lxml")
    d = soup.find('document')
    fl = 0
    wfs = []
    for c in d.children:
        if c.name == 'header':
            fl = 1
        if fl:
#Tokenizing text that received no annotation and adding the 'O' tag to every word in it
#Неразмеченный текст токенизируем и приписываем помету 'O'
            if c.name == None:
                ws = tokenizers.simple_word_tokenize(c.title())
                for w in ws:
                    d = {'word': w, 'label':'O'}
                    wfs.append(d)
#Reading annotation info for words which received relevant annotation:
#Размеченные слова: 
            elif c.name == 'segment':
                d = {'word': c.get_text()}
                ann = c.get('features').split(u';')
#Chacking annotation and assigning annotation tags to words
#Проверяем разметку и приписываем соответствующие значения словам
                if len(ann) == 2 and ann[1][-1] != u'_':
                    d['label'] = ann[1]
                else:
                    d['label'] = 'O'
                #print (d)
                wfs.append(d)
    return wfs

# %% [markdown]
# Feature extraction for every wordform:
#
# -long list: word, normal form, first 2 and 5 letters, case and digits, part of speech, tense and person (for verbs);
#
# -short list (for words over 1 word away from the current one): word, first 5 letters, part of speech.
#
#
# *Вычисляем параметры для всех словоформ:*
#
# *длинный список: слово, нормальная форма, первые 2 и 5 букв слова, хар-ки регистра и цифры, часть речи, время (глагола), лицо (глагола)
# короткий список (для отдаленных слов): слово, первые 5 букв, часть речи.*

# %%
m = pm.MorphAnalyzer()
def wordfeats(word, pref = ''):
    wl = word.lower()
    t = m.tag(word)[0]
    feats = {
        pref + 'lower': wl,
        pref + 'word_2': wl[:2],
        pref + 'word_5': wl[:5],
        pref + 'lemma': m.normal_forms(word)[0],
        pref + 'isupper': word.isupper(),
        pref + 'istitle': word.istitle(),
        pref + 'isdigit': word.isdigit(),
        pref + 'postag': str(t.POS),
        pref + 'tense': str(t.tense),
        pref + 'person': str(t.person) 
    }
    return feats

def minifeats(word, pref = ''):
    wl = word.lower()
    t = m.tag(word)[0]
    feats = {
        pref + 'lower': wl,
        pref + 'word_5': wl[:5],
        pref + 'postag': str(t.POS),
    }
    return feats

def getfeats(text, i):
    word = text[i]
    feats = wordfeats(text[i])
    if i > 0:
        feats.update(wordfeats(text[i-1], pref = 'mi_'))
    if i < len(text)-1:
        feats.update(wordfeats(text[i+1], pref = 'pl_'))
    if i < len(text)-2:
        feats.update(minifeats(text[i+2], pref = 'pl2_'))
    return feats

# %% [markdown]
# Reading xml's and extracting features
#
# *Читаем xml и вычисляем параметры*

# %%
def geddicts(foo):
    fns = os.listdir(foo)
    allfs = []
    allbs = []
    for fn in fns:
        #print (fn)
        wfs = parsefile(foo + fn)
        ws = [d['word'] for d in wfs]
        labels = [d['label'] for d in wfs]
        feats = [getfeats(ws, i) for i, w in enumerate(ws)]
        print (fn, '\t', len(ws), 'words')
        allfs.append(feats)
        allbs.append(labels)
    #df = pd.DataFrame(allfs)
    #df['label'] = allbs
    #df.to_csv(u'c:\D\PolinaP\work\ifmo\data\\' + resfn)
    return np.array(allfs), np.array(allbs), fns

# %% [markdown]
# Experiment settings:
#
# 3-fold cross-validation (document-based), training a conditional random fields classifier, evaluation (flat_classification_report - words-based)
#
#
# *Проводим эксперимент:*
# *3-х-кратная кросс-валидация по документам, обучение conditional random fields, тестирование и оценка результатов по индивидуальным словам (flat_classification_report), а не документам.*

# %%
def evalcrf(X, y):
    kf = KFold(n_splits=3, shuffle=True)
    alltest = np.array([])
    allpred = np.array([])
    testind = np.array([], int)
    for train, test in kf.split(X):
        X_train = X[train]
        y_train = y[train]
        X_test = X[test]
        y_test = y[test]
#Taking some initial hyper-parameter values from the crf-suite documentation
#The hyper-parameters could be additionally tuned with the data
#Берем гиперпараметры классификатора навскидку из документации библиотеки crfsuite.
#В дальнейшем гиперпараметры можно будет подобрать на обучающей выборке.
        crf = sklearn_crfsuite.CRF(
        algorithm='lbfgs', 
        c1=0.1, 
        c2=0.1, 
        max_iterations=100, 
        all_possible_transitions=True)
    
        crf.fit(X_train, y_train)
        y_pred = crf.predict(X_test)

        alltest = np.concatenate((alltest, y_test))
        allpred = np.concatenate((allpred, y_pred))
        testind = np.concatenate((testind, test))

#Results output for the relevant classes: (neg, phen_b, phen_i), excluding the 'O'-class        
#Выводим результаты только для интересующих нас классов (neg, phen_b, phen_i), без "нулевого" класса O    
    labels = list(crf.classes_)
    labels.remove('O')

    print(metrics.flat_classification_report(
            alltest, allpred, labels=labels, digits=3
        ))
    return alltest, allpred, testind

# %% [markdown]
# Reading actual data and extracting features
#
# *Читаем данные и вычисляем параметры*

# %%
foo = r'.\annotated_data\\'
cfeatures, clabels, fns = geddicts(foo)
print(u'Документов: ', len(cfeatures))
# Out:
# 10003_С2015 11856_С2015.xml.xml 	 296 words
# 10004_С2011 10494_С2011.xml.xml 	 405 words
# 10004_С2015.xml.xml 	 275 words
# 10006_С2013.xml.xml 	 11 words
# 10007_С2013.xml.xml 	 154 words
# 10008_С2012.xml.xml 	 176 words
# 10008_С2015.xml.xml 	 212 words
# 10010_С2012.xml.xml 	 67 words
# 10011_С2013.xml.xml 	 141 words
# 10012_С2013.xml.xml 	 11 words
# 10013_С2013.xml.xml 	 107 words
# 10014_С2013.xml.xml 	 11 words
# 10015_С2012.xml.xml 	 5 words
# 10015_С2013.xml.xml 	 11 words
# 10016_С2013.xml.xml 	 111 words
# 10021_С2015.xml.xml 	 1097 words
# 10031_С2011.xml.xml 	 80 words
# 10039_С2011.xml.xml 	 175 words
# 1004_С2015.xml.xml 	 11 words
# 10083_С2011.xml.xml 	 116 words
# 10092_С2012.xml.xml 	 83 words
# 10099_С2010.xml.xml 	 97 words
# 10101_С2010 10540_С2010 11638_С2010.xml.xml 	 552 words
# 10107_С2011.xml.xml 	 162 words
# 10109_С2011.xml.xml 	 155 words
# 10113_С2011.xml.xml 	 234 words
# 10114_С2011.xml.xml 	 116 words
# 10145_С2010.xml.xml 	 24 words
# 10149_С2011 10612_С2011.xml.xml 	 148 words
# 10151_С2011 14936_С2011.xml.xml 	 389 words
# 10153_С2011.xml.xml 	 85 words
# 10159_С2011 11288_С2011 12129_С2011.xml.xml 	 384 words
# 10161_С2011.xml.xml 	 109 words
# 10163_С2011 11319_С2011.xml.xml 	 283 words
# 10164_С2012.xml.xml 	 11 words
# 10171_С2011.xml.xml 	 167 words
# 10178_С2011.xml.xml 	 205 words
# 10179_С2014.xml.xml 	 133 words
# 10180_С2014.xml.xml 	 298 words
# 10195_С2011.xml.xml 	 9 words
# 10196_С2015.xml.xml 	 134 words
# 10219_С2011.xml.xml 	 384 words
# 10219_С2015.xml.xml 	 152 words
# 10225_С2013.xml.xml 	 46 words
# 10235_С2015.xml.xml 	 171 words
# 10238_С2012.xml.xml 	 81 words
# 10248_С2012 133_О2012.xml.xml 	 262 words
# 10249_С2012.xml.xml 	 193 words
# 10260_С2013.xml.xml 	 187 words
# 10263_С2011.xml.xml 	 142 words
# 10265_С2011.xml.xml 	 107 words
# 10266_С2011.xml.xml 	 44 words
# 10271_С2010.xml.xml 	 109 words
# 10282_С2014 10369_С2014.xml.xml 	 8 words
# 10282_С2015 11064_С2015.xml.xml 	 182 words
# 10286_С2014.xml.xml 	 787 words
# 10293_С2014.xml.xml 	 314 words
# 10295_С2014.xml.xml 	 93 words
# 10299_С2010 10868_С2010.xml.xml 	 274 words
# 10300_С2014.xml.xml 	 336 words
# 10302_С2010.xml.xml 	 99 words
# 10317_С2015.xml.xml 	 183 words
# 10333_С2012.xml.xml 	 409 words
# 10338_С2015.xml.xml 	 342 words
# 10343_С2013.xml.xml 	 252 words
# 10357_С2013.xml.xml 	 163 words
# 10370_С2014.xml.xml 	 218 words
# 1038_С2015.xml.xml 	 9 words
# 10393_С2011 10578_С2011.xml.xml 	 113 words
# 10398_С2010.xml.xml 	 115 words
# 10412_С2010.xml.xml 	 94 words
# 10416_С2010.xml.xml 	 145 words
# 10419_С2011 10574_С2011.xml.xml 	 65 words
# 1041_С2012.xml.xml 	 130 words
# 10421_С2011 10576_С2011.xml.xml 	 157 words
# 10423_С2011.xml.xml 	 179 words
# 10423_С2015.xml.xml 	 156 words
# 10424_С2011.xml.xml 	 123 words
# 1043_С2013.xml.xml 	 228 words
# 10440_С2010 11124_C2010.xml.xml 	 262 words
# Документов:  80

# %% [markdown]
# Experiment with actual data. Results output on relevant classes.
#
# *Эксперимент с данными. Выводим результаты по интересующим нас классам.*

# %%
alltest, allpred, testind = evalcrf(cfeatures, clabels)
# Out:
#              precision    recall  f1-score   support
#
#      phen-b      0.862     0.855     0.858       110
#      phen-i      0.884     0.894     0.889       274
#         neg      0.906     0.928     0.917       125
#
# avg / total      0.885     0.894     0.889       509

# %% [markdown]
# Output of errors by documents and words
#
# *Вывод ошибок по документам и словам*

# %%
for i, d in enumerate(alltest):
    print(fns[testind[i]])
    for j, lab in enumerate(d):
        if lab != allpred[i][j]:
            print(j, cfeatures[testind[i]][j]['lower'], lab, allpred[i][j])
# Out:
# 10007_С2013.xml.xml
# 75 болей phen-i phen-b
# 10008_С2012.xml.xml
# 0 анамнез phen-b O
# 1 гипертонической phen-i phen-b
# 162 осложнений O phen-b
# 163 не O neg
# 164 было O phen-i
# 10010_С2012.xml.xml
# 10015_С2013.xml.xml
# 10016_С2013.xml.xml
# 10039_С2011.xml.xml
# 1004_С2015.xml.xml
# 10101_С2010 10540_С2010 11638_С2010.xml.xml
# 10107_С2011.xml.xml
# 10114_С2011.xml.xml
# 0 анамнеза phen-b O
# 1 аг phen-i O
# 2 нет neg O
# 10149_С2011 10612_С2011.xml.xml
# 10178_С2011.xml.xml
# 10180_С2014.xml.xml
# 10195_С2011.xml.xml
# 10219_С2015.xml.xml
# 87 повышение phen-b O
# 88 ад phen-i O
# 89 : phen-i O
# 90 давность phen-i O
# 91 не neg O
# 92 отмечает phen-i O
# 10225_С2013.xml.xml
# 10235_С2015.xml.xml
# 10238_С2012.xml.xml
# 76 лечение phen-b O
# 77 : phen-i O
# 10263_С2011.xml.xml
# 19 постоянно O phen-b
# 20 ад phen-b phen-i
# 44 без neg O
# 45 иррадиации phen-i O
# 10286_С2014.xml.xml
# 775 ангинозные phen-b O
# 776 боли phen-i O
# 777 : phen-i O
# 778 нек neg O
# 779 рецидивируют phen-i O
# 10333_С2012.xml.xml
# 376 статинами O phen-b
# 377 боли phen-b phen-i
# 10338_С2015.xml.xml
# 10343_С2013.xml.xml
# 1038_С2015.xml.xml
# 10416_С2010.xml.xml
# 1043_С2013.xml.xml
# 10440_С2010 11124_C2010.xml.xml
# 49 постоянной phen-i phen-b
# 158 без neg O
# 159 ангинозных phen-i O
# 160 болей phen-i O
# 10004_С2011 10494_С2011.xml.xml
# 10004_С2015.xml.xml
# 156 без O neg
# 157 гемодинамически O phen-i
# 158 значимого O phen-i
# 159 стенозирования O phen-i
# 233 отделении O phen-b
# 234 самочувствие phen-b phen-i
# 244 без O neg
# 245 признаков O phen-i
# 246 воспаления O phen-i
# 247 . O phen-i
# 248 не O neg
# 249 лихорадила O phen-i
# 251 ангинозные phen-b O
# 252 боли phen-i O
# 253 не neg O
# 254 рецидивировали phen-i O
# 10008_С2015.xml.xml
# 81 без O neg
# 82 гемодинамически O phen-i
# 83 значимого O phen-i
# 84 стенозирования O phen-i
# 103 без O neg
# 104 осложнений O phen-i
# 107 без O neg
# 108 сущ. O phen-i
# 109 повышения O phen-i
# 10011_С2013.xml.xml
# 76 без O neg
# 77 эффекта O phen-i
# 10031_С2011.xml.xml
# 10092_С2012.xml.xml
# 69 : O phen-i
# 10099_С2010.xml.xml
# 10109_С2011.xml.xml
# 10113_С2011.xml.xml
# 10145_С2010.xml.xml
# 10151_С2011 14936_С2011.xml.xml
# 10153_С2011.xml.xml
# 10159_С2011 11288_С2011 12129_С2011.xml.xml
# 21 за phen-b O
# 22 медицинской phen-i phen-b
# 10161_С2011.xml.xml
# 10163_С2011 11319_С2011.xml.xml
# 10196_С2015.xml.xml
# 113 сахарный phen-b O
# 114 диабет phen-i O
# 115 , phen-i O
# 116 онмк phen-i phen-b
# 10219_С2011.xml.xml
# 10248_С2012 133_О2012.xml.xml
# 10260_С2013.xml.xml
# 10265_С2011.xml.xml
# 10266_С2011.xml.xml
# 10293_С2014.xml.xml
# 10300_С2014.xml.xml
# 29 кардиалгий phen-b O
# 30 , phen-i O
# 31 нехватки phen-i phen-b
# 161 данные phen-b O
# 162 не neg O
# 163 оценивались phen-i O
# 164 кардиологом phen-i O
# 10302_С2010.xml.xml
# 10393_С2011 10578_С2011.xml.xml
# 10419_С2011 10574_С2011.xml.xml
# 10424_С2011.xml.xml
# 10003_С2015 11856_С2015.xml.xml
# 91 иррадиации phen-b phen-i
# 247 ангинозные O phen-b
# 248 боли O phen-i
# 249 не O neg
# 250 рецидивировали O phen-i
# 10006_С2013.xml.xml
# 10012_С2013.xml.xml
# 10013_С2013.xml.xml
# 10014_С2013.xml.xml
# 10015_С2012.xml.xml
# 10021_С2015.xml.xml
# 39 без neg O
# 40 регулярной phen-i O
# 41 гипотензивной phen-i O
# 42 терапии phen-i O
# 53 без neg O
# 54 адекватной phen-b O
# 55 терапии phen-i O
# 234 ишемических O phen-b
# 235 изменений O phen-i
# 236 не O neg
# 237 выявлено O phen-i
# 973 достоверные O phen-b
# 974 ишемические O phen-i
# 975 изменения O phen-i
# 976 экг O phen-i
# 977 не O neg
# 978 обнаружены O phen-i
# 980 жнр O phen-b
# 981 высоких O phen-i
# 982 градаций O phen-i
# 983 не O neg
# 984 выявлены O phen-i
# 10083_С2011.xml.xml
# 10164_С2012.xml.xml
# 10171_С2011.xml.xml
# 10179_С2014.xml.xml
# 10249_С2012.xml.xml
# 10271_С2010.xml.xml
# 10282_С2014 10369_С2014.xml.xml
# 10282_С2015 11064_С2015.xml.xml
# 10295_С2014.xml.xml
# 10299_С2010 10868_С2010.xml.xml
# 10317_С2015.xml.xml
# 112 анамнезе O phen-b
# 113 онмк phen-b phen-i
# 10357_С2013.xml.xml
# 10370_С2014.xml.xml
# 10398_С2010.xml.xml
# 10412_С2010.xml.xml
# 1041_С2012.xml.xml
# 10421_С2011 10576_С2011.xml.xml
# 10423_С2011.xml.xml
# 10423_С2015.xml.xml

# %% [markdown]
# Output of correct results by documents and words
#
# *Вывод верных срабатываний по документам и словам*

# %%
for i, d in enumerate(alltest):
    print(fns[testind[i]])
    for j, lab in enumerate(d):
        if lab == allpred[i][j] and lab != 'O':
            print(j, cfeatures[testind[i]][j]['lower'], lab, allpred[i][j])
# Out:
# 10007_С2013.xml.xml
# 19 не neg neg
# 20 наблюдалась phen-i phen-i
# 22 лекарственные phen-b phen-b
# 23 препараты phen-i phen-i
# 24 не neg neg
# 25 принимала phen-i phen-i
# 59 без neg neg
# 60 иррадиации phen-i phen-i
# 63 не neg neg
# 64 купировалась phen-i phen-i
# 76 не neg neg
# 77 было phen-i phen-i
# 84 госпитализация phen-b phen-b
# 85 не neg neg
# 86 предлагалась phen-i phen-i
# 149 лекарственные phen-b phen-b
# 150 препараты phen-i phen-i
# 151 не neg neg
# 152 принимала phen-i phen-i
# 10008_С2012.xml.xml
# 2 болезни phen-i phen-i
# 3 отрицает neg neg
# 30 регулярную phen-b phen-b
# 31 терапию phen-i phen-i
# 32 не neg neg
# 33 получал phen-i phen-i
# 78 ангинозные phen-b phen-b
# 79 боли phen-i phen-i
# 80 не neg neg
# 81 беспокоили phen-i phen-i
# 10010_С2012.xml.xml
# 10015_С2013.xml.xml
# 10016_С2013.xml.xml
# 15 повышение phen-b phen-b
# 16 ад phen-i phen-i
# 17 отрицает neg neg
# 55 онмк phen-b phen-b
# 56 : phen-i phen-i
# 57 отрицает neg neg
# 10039_С2011.xml.xml
# 167 ангинозные phen-b phen-b
# 168 боли phen-i phen-i
# 169 , phen-i phen-i
# 170 нарушения phen-i phen-i
# 171 ритма phen-i phen-i
# 172 не neg neg
# 173 рецидивировали phen-i phen-i
# 1004_С2015.xml.xml
# 10101_С2010 10540_С2010 11638_С2010.xml.xml
# 10107_С2011.xml.xml
# 111 ангинозные phen-b phen-b
# 112 боли phen-i phen-i
# 113 не neg neg
# 114 рецидивировали phen-i phen-i
# 10114_С2011.xml.xml
# 10149_С2011 10612_С2011.xml.xml
# 10178_С2011.xml.xml
# 41 ангинозных phen-b phen-b
# 42 болей phen-i phen-i
# 43 не neg neg
# 44 было phen-i phen-i
# 147 ангинозные phen-b phen-b
# 148 боли phen-i phen-i
# 149 не neg neg
# 150 рецидивировали phen-i phen-i
# 10180_С2014.xml.xml
# 36 наличие phen-b phen-b
# 37 онмк phen-i phen-i
# 38 в phen-i phen-i
# 39 анамнезе phen-i phen-i
# 40 отрицает neg neg
# 271 ангинозные phen-b phen-b
# 272 боли phen-i phen-i
# 273 не neg neg
# 274 рецидивировали phen-i phen-i
# 10195_С2011.xml.xml
# 10219_С2015.xml.xml
# 10225_С2013.xml.xml
# 1 у phen-b phen-b
# 2 уролога phen-i phen-i
# 3 не neg neg
# 4 наблюдалась phen-i phen-i
# 10235_С2015.xml.xml
# 10238_С2012.xml.xml
# 42 заболевания phen-b phen-b
# 43 почек phen-i phen-i
# 44 : phen-i phen-i
# 45 отрицает neg neg
# 46 ангинозные phen-b phen-b
# 47 боли phen-i phen-i
# 48 : phen-i phen-i
# 49 не neg neg
# 50 беспокоили phen-i phen-i
# 52 инфаркт phen-b phen-b
# 53 миокарда phen-i phen-i
# 54 : phen-i phen-i
# 55 отрицает neg neg
# 57 онмк phen-b phen-b
# 58 : phen-i phen-i
# 59 отрицает neg neg
# 78 не neg neg
# 79 получал phen-i phen-i
# 10263_С2011.xml.xml
# 21 не neg neg
# 22 контролировал phen-i phen-i
# 24 антигипертензивной phen-b phen-b
# 25 терапии phen-i phen-i
# 26 не neg neg
# 27 получал phen-i phen-i
# 10286_С2014.xml.xml
# 35 к phen-b phen-b
# 36 специалистам phen-i phen-i
# 37 не neg neg
# 38 обращался phen-i phen-i
# 40 обследование phen-b phen-b
# 41 не neg neg
# 42 проходил phen-i phen-i
# 44 препараты phen-b phen-b
# 45 постоянно phen-i phen-i
# 46 не neg neg
# 47 принимал phen-i phen-i
# 328 ангинозные phen-b phen-b
# 329 боли phen-i phen-i
# 330 не neg neg
# 331 рецидивировали phen-i phen-i
# 771 заболевания phen-b phen-b
# 772 почек phen-i phen-i
# 773 : phen-i phen-i
# 774 отрицает neg neg
# 10333_С2012.xml.xml
# 378 за phen-i phen-i
# 379 грудиной phen-i phen-i
# 380 не neg neg
# 381 рецидивировали phen-i phen-i
# 10338_С2015.xml.xml
# 53 ангинозные phen-b phen-b
# 54 приступы phen-i phen-i
# 55 отрицает neg neg
# 218 ангинозные phen-b phen-b
# 219 приступ phen-i phen-i
# 220 не neg neg
# 221 рецидивировали phen-i phen-i
# 10343_С2013.xml.xml
# 58 к phen-b phen-b
# 59 мед phen-i phen-i
# 60 . phen-i phen-i
# 61 персоналу phen-i phen-i
# 62 не neg neg
# 63 обращалась phen-i phen-i
# 65 со phen-b phen-b
# 66 слов phen-i phen-i
# 67 , phen-i phen-i
# 68 по phen-i phen-i
# 69 данным phen-i phen-i
# 70 фгдс phen-i phen-i
# 71 - phen-i phen-i
# 72 без neg neg
# 73 патологии phen-i phen-i
# 132 болевой phen-b phen-b
# 133 синдром phen-i phen-i
# 134 не neg neg
# 135 рецидивировал phen-i phen-i
# 187 ангинозные phen-b phen-b
# 188 боли phen-i phen-i
# 189 не neg neg
# 190 рецидивировали phen-i phen-i
# 1038_С2015.xml.xml
# 10416_С2010.xml.xml
# 1 артериальное phen-b phen-b
# 2 давление phen-i phen-i
# 3 не neg neg
# 4 повышалось phen-i phen-i
# 38 к phen-b phen-b
# 39 врачу phen-i phen-i
# 40 не neg neg
# 41 обращался phen-i phen-i
# 43 нитратами phen-b phen-b
# 44 не neg neg
# 45 пользовался phen-i phen-i
# 1043_С2013.xml.xml
# 21 контроль phen-b phen-b
# 22 давления phen-i phen-i
# 23 не neg neg
# 24 проводился phen-i phen-i
# 26 базисной phen-b phen-b
# 27 терапии phen-i phen-i
# 28 не neg neg
# 29 получал phen-i phen-i
# 177 заболевания phen-b phen-b
# 178 почек phen-i phen-i
# 179 : phen-i phen-i
# 180 отрицает neg neg
# 191 инфаркт phen-b phen-b
# 192 миокарда phen-i phen-i
# 193 : phen-i phen-i
# 194 отрицает neg neg
# 195 онмк phen-b phen-b
# 196 : phen-i phen-i
# 197 отрицает neg neg
# 10440_С2010 11124_C2010.xml.xml
# 48 без neg neg
# 50 терапии phen-i phen-i
# 10004_С2011 10494_С2011.xml.xml
# 113 за phen-b phen-b
# 114 результатами phen-i phen-i
# 115 цитологии phen-i phen-i
# 116 пациент phen-i phen-i
# 117 не neg neg
# 118 обращался phen-i phen-i
# 122 у phen-b phen-b
# 123 эндокринолога phen-i phen-i
# 124 не neg neg
# 125 лечился phen-i phen-i
# 10004_С2015.xml.xml
# 235 без neg neg
# 236 ухудшения phen-i phen-i
# 10008_С2015.xml.xml
# 10011_С2013.xml.xml
# 10031_С2011.xml.xml
# 10092_С2012.xml.xml
# 63 инфаркт phen-b phen-b
# 64 миокарда phen-i phen-i
# 65 : phen-i phen-i
# 66 ранее phen-i phen-i
# 67 отрицает neg neg
# 68 онмк phen-b phen-b
# 70 отрицает neg neg
# 10099_С2010.xml.xml
# 10109_С2011.xml.xml
# 10113_С2011.xml.xml
# 161 ангинозные phen-b phen-b
# 162 боли phen-i phen-i
# 163 не neg neg
# 164 рецидивировали phen-i phen-i
# 10145_С2010.xml.xml
# 10151_С2011 14936_С2011.xml.xml
# 10153_С2011.xml.xml
# 10 повышение phen-b phen-b
# 11 ад phen-i phen-i
# 12 отрицает neg neg
# 23 заболевания phen-b phen-b
# 24 почек phen-i phen-i
# 25 : phen-i phen-i
# 26 отрицает neg neg
# 46 инфаркт phen-b phen-b
# 47 миокарда phen-i phen-i
# 48 : phen-i phen-i
# 49 ранее phen-i phen-i
# 50 отрицает neg neg
# 51 онмк phen-b phen-b
# 52 : phen-i phen-i
# 53 отрицает neg neg
# 10159_С2011 11288_С2011 12129_С2011.xml.xml
# 23 помощью phen-i phen-i
# 24 не neg neg
# 25 обращался phen-i phen-i
# 10161_С2011.xml.xml
# 33 заболевания phen-b phen-b
# 34 почек phen-i phen-i
# 35 : phen-i phen-i
# 36 отрицает neg neg
# 69 онмк phen-b phen-b
# 70 : phen-i phen-i
# 71 отрицает neg neg
# 10163_С2011 11319_С2011.xml.xml
# 0 артериальное phen-b phen-b
# 1 давление phen-i phen-i
# 2 ранее phen-i phen-i
# 3 не neg neg
# 4 повышалось phen-i phen-i
# 155 нитраты phen-b phen-b
# 156 не neg neg
# 157 принимал phen-i phen-i
# 10196_С2015.xml.xml
# 117 , phen-i phen-i
# 118 ба phen-i phen-i
# 119 , phen-i phen-i
# 120 заболевания phen-i phen-i
# 121 щж phen-i phen-i
# 122 : phen-i phen-i
# 123 отрицает neg neg
# 10219_С2011.xml.xml
# 10248_С2012 133_О2012.xml.xml
# 10260_С2013.xml.xml
# 0 анамнез phen-b phen-b
# 1 аг phen-i phen-i
# 2 отрицает neg neg
# 17 не neg neg
# 18 обследовался phen-i phen-i
# 20 антиангинальной phen-b phen-b
# 21 терапии phen-i phen-i
# 22 не neg neg
# 23 получал phen-i phen-i
# 10265_С2011.xml.xml
# 39 заболевания phen-b phen-b
# 40 почек phen-i phen-i
# 41 : phen-i phen-i
# 42 отрицает neg neg
# 58 онмк phen-b phen-b
# 59 : phen-i phen-i
# 60 отрицает neg neg
# 10266_С2011.xml.xml
# 7 у phen-b phen-b
# 8 невролога phen-i phen-i
# 9 не neg neg
# 10 наблюдался phen-i phen-i
# 10293_С2014.xml.xml
# 35 постоянной phen-b phen-b
# 36 антигипертензивной phen-i phen-i
# 37 терапии phen-i phen-i
# 38 не neg neg
# 39 принимал phen-i phen-i
# 41 наличие phen-b phen-b
# 42 онмк phen-i phen-i
# 43 в phen-i phen-i
# 44 анамнезе phen-i phen-i
# 45 отрицает neg neg
# 53 болей phen-b phen-b
# 54 ангинозного phen-i phen-i
# 55 характера phen-i phen-i
# 56 не neg neg
# 57 отмечал phen-i phen-i
# 166 повышение phen-b phen-b
# 167 температуры phen-i phen-i
# 168 тела phen-i phen-i
# 169 пациент phen-i phen-i
# 170 отрицает neg neg
# 10300_С2014.xml.xml
# 6 ад phen-b phen-b
# 7 не neg neg
# 8 контролировал phen-i phen-i
# 10 к phen-b phen-b
# 11 врачам phen-i phen-i
# 12 не neg neg
# 13 обращался phen-i phen-i
# 32 воздуха phen-i phen-i
# 33 не neg neg
# 34 описывал phen-i phen-i
# 54 со phen-b phen-b
# 55 слов phen-i phen-i
# 56 , phen-i phen-i
# 57 по phen-i phen-i
# 58 данным phen-i phen-i
# 59 экг phen-i phen-i
# 60 - phen-i phen-i
# 61 без neg neg
# 62 изменений phen-i phen-i
# 64 госпитализации phen-b phen-b
# 65 не neg neg
# 66 предлагали phen-i phen-i
# 112 названия phen-b phen-b
# 113 препаратов phen-i phen-i
# 114 не neg neg
# 115 помнит phen-i phen-i
# 311 ангинозные phen-b phen-b
# 312 боли phen-i phen-i
# 313 не neg neg
# 314 рецидивировали phen-i phen-i
# 10302_С2010.xml.xml
# 1 аретриальное phen-b phen-b
# 2 давление phen-i phen-i
# 3 не neg neg
# 4 повышалось phen-i phen-i
# 85 в phen-b phen-b
# 86 послеоперационном phen-i phen-i
# 87 периоде phen-i phen-i
# 88 осложнений phen-i phen-i
# 89 не neg neg
# 90 было phen-i phen-i
# 10393_С2011 10578_С2011.xml.xml
# 0 без neg neg
# 1 анамнеза phen-i phen-i
# 2 аг phen-i phen-i
# 10419_С2011 10574_С2011.xml.xml
# 10424_С2011.xml.xml
# 17 не neg neg
# 18 обследовался phen-i phen-i
# 20 не neg neg
# 21 лечился phen-i phen-i
# 103 ангинозные phen-b phen-b
# 104 боли phen-i phen-i
# 105 , phen-i phen-i
# 106 нарушения phen-i phen-i
# 107 ритма phen-i phen-i
# 108 не neg neg
# 109 отмечал phen-i phen-i
# 10003_С2015 11856_С2015.xml.xml
# 38 ад phen-b phen-b
# 39 постоянно phen-i phen-i
# 40 не neg neg
# 41 мониторирует phen-i phen-i
# 73 ангинозные phen-b phen-b
# 74 боли phen-i phen-i
# 75 не neg neg
# 76 бесспокоили phen-i phen-i
# 90 без neg neg
# 113 спм phen-b phen-b
# 114 не neg neg
# 115 вызывал phen-i phen-i
# 10006_С2013.xml.xml
# 10012_С2013.xml.xml
# 10013_С2013.xml.xml
# 13 не neg neg
# 14 обращалась phen-i phen-i
# 38 заболевания phen-b phen-b
# 39 почек phen-i phen-i
# 40 : phen-i phen-i
# 41 отрицает neg neg
# 69 инфаркт phen-b phen-b
# 70 миокарда phen-i phen-i
# 71 : phen-i phen-i
# 72 ранее phen-i phen-i
# 73 отрицает neg neg
# 74 онмк phen-b phen-b
# 75 : phen-i phen-i
# 76 отрицает neg neg
# 10014_С2013.xml.xml
# 10015_С2012.xml.xml
# 10021_С2015.xml.xml
# 34 генез phen-b phen-b
# 35 аг phen-i phen-i
# 36 не neg neg
# 37 уточнялся phen-i phen-i
# 884 ангинозные phen-b phen-b
# 885 боли phen-i phen-i
# 886 не neg neg
# 887 рецидивировали phen-i phen-i
# 10083_С2011.xml.xml
# 10164_С2012.xml.xml
# 10171_С2011.xml.xml
# 10179_С2014.xml.xml
# 44 инфаркт phen-b phen-b
# 45 миокарда phen-i phen-i
# 46 : phen-i phen-i
# 47 ранее phen-i phen-i
# 48 отрицает neg neg
# 49 онмк phen-b phen-b
# 50 : phen-i phen-i
# 51 отрицает neg neg
# 10249_С2012.xml.xml
# 27 не neg neg
# 28 обследовался phen-i phen-i
# 10271_С2010.xml.xml
# 94 болевой phen-b phen-b
# 95 синдром phen-i phen-i
# 96 в phen-i phen-i
# 97 грудной phen-i phen-i
# 98 клетке phen-i phen-i
# 99 не neg neg
# 100 рецидивирует phen-i phen-i
# 10282_С2014 10369_С2014.xml.xml
# 10282_С2015 11064_С2015.xml.xml
# 18 по phen-b phen-b
# 19 поводу phen-i phen-i
# 20 аг phen-i phen-i
# 21 не neg neg
# 22 обследована phen-i phen-i
# 67 к phen-b phen-b
# 68 врачам phen-i phen-i
# 69 не neg neg
# 70 обращалась phen-i phen-i
# 10295_С2014.xml.xml
# 10299_С2010 10868_С2010.xml.xml
# 90 к phen-b phen-b
# 91 врачу phen-i phen-i
# 92 не neg neg
# 93 обращался phen-i phen-i
# 10317_С2015.xml.xml
# 114 , phen-i phen-i
# 115 ба phen-i phen-i
# 116 , phen-i phen-i
# 117 заболевания phen-i phen-i
# 118 щж phen-i phen-i
# 119 : phen-i phen-i
# 120 отрицает neg neg
# 121 инфаркт phen-b phen-b
# 122 миокарда phen-i phen-i
# 123 : phen-i phen-i
# 124 отрицает neg neg
# 10357_С2013.xml.xml
# 52 постоянной phen-b phen-b
# 53 антигипертензивной phen-i phen-i
# 54 терапии phen-i phen-i
# 55 не neg neg
# 56 получает phen-i phen-i
# 68 оим phen-b phen-b
# 69 в phen-i phen-i
# 70 анамнезе phen-i phen-i
# 71 отрицает neg neg
# 10370_С2014.xml.xml
# 189 без neg neg
# 190 ухудшений phen-i phen-i
# 10398_С2010.xml.xml
# 21 к phen-b phen-b
# 22 врачам phen-i phen-i
# 23 не neg neg
# 24 обращался phen-i phen-i
# 66 о phen-b phen-b
# 67 повышении phen-i phen-i
# 68 ад phen-i phen-i
# 69 в phen-i phen-i
# 70 анамнезе phen-i phen-i
# 71 не neg neg
# 72 знает phen-i phen-i
# 82 постоянной phen-b phen-b
# 83 антигипертензивной phen-i phen-i
# 84 терапии phen-i phen-i
# 85 не neg neg
# 86 получал phen-i phen-i
# 104 постоянной phen-b phen-b
# 105 антиаритмической phen-i phen-i
# 106 терапии phen-i phen-i
# 107 не neg neg
# 108 получал phen-i phen-i
# 10412_С2010.xml.xml
# 1041_С2012.xml.xml
# 57 оим phen-b phen-b
# 58 не neg neg
# 59 переносила phen-i phen-i
# 10421_С2011 10576_С2011.xml.xml
# 10423_С2011.xml.xml
# 10423_С2015.xml.xml
# 10 ад phen-b phen-b
# 11 не neg neg
# 12 контролирует phen-i phen-i
# 15 клинику phen-b phen-b
# 16 стенокардии phen-i phen-i
# 17 отрицает neg neg
# 32 за phen-b phen-b
# 33 мед phen-i phen-i
# 34 . phen-i phen-i
# 35 помощью phen-i phen-i
# 36 не neg neg
# 37 обращалась phen-i phen-i
